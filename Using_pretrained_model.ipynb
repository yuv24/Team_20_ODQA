# %%
pip install transformers gradio
# Out:
# Requirement already satisfied: transformers in c:\python 3105\lib\site-packages (4.40.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: gradio in c:\python 3105\lib\site-packages (5.8.0)
# Requirement already satisfied: filelock in c:\python 3105\lib\site-packages (from transformers) (3.14.0)
# Requirement already satisfied: requests in c:\python 3105\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\python 3105\lib\site-packages (from transformers) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in c:\python 3105\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\python 3105\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\python 3105\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\python 3105\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\python 3105\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\python 3105\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\python 3105\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\python 3105\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\python 3105\lib\site-packages (from gradio) (0.8.2)
# Requirement already satisfied: orjson~=3.0 in c:\python 3105\lib\site-packages (from gradio) (3.10.12)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\python 3105\lib\site-packages (from gradio) (0.41.3)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\python 3105\lib\site-packages (from gradio) (0.32.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\python 3105\lib\site-packages (from gradio) (11.0.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\python 3105\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\python 3105\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\python 3105\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\python 3105\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in c:\python 3105\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: ffmpy in c:\python 3105\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: pydub in c:\python 3105\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: gradio-client==1.5.1 in c:\python 3105\lib\site-packages (from gradio) (1.5.1)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\python 3105\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\python 3105\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\python 3105\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\python 3105\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\python 3105\lib\site-packages (from gradio) (0.115.6)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\python 3105\lib\site-packages (from gradio) (0.0.19)
# Requirement already satisfied: markupsafe~=2.0 in c:\python 3105\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: pydantic>=2.0 in c:\python 3105\lib\site-packages (from gradio) (2.10.2)
# Requirement already satisfied: fsspec in c:\python 3105\lib\site-packages (from gradio-client==1.5.1->gradio) (2024.5.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\python 3105\lib\site-packages (from gradio-client==1.5.1->gradio) (14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\python 3105\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\python 3105\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\python 3105\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\python 3105\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\python 3105\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\python 3105\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python 3105\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python 3105\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python 3105\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python 3105\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\python 3105\lib\site-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: colorama in c:\python 3105\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: click>=8.0.0 in c:\python 3105\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.3)
# Requirement already satisfied: rich>=10.11.0 in c:\python 3105\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\python 3105\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python 3105\lib\site-packages (from requests->transformers) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python 3105\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\python 3105\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python 3105\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\python 3105\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\python 3105\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\python 3105\python.exe -m pip install --upgrade pip' command.

# %%
from transformers import pipeline
import gradio as gr

# Load the GPT-Neo 1.3B model (around 2.5GB)
generator = pipeline("text-generation", model="EleutherAI/gpt-neo-1.3B", device_map="auto")

# Define a function to generate answers
def generate_response(prompt, max_length, temperature):
    """
    Generate text based on user input.

    Args:
    - prompt (str): The input text from the user.
    - max_length (int): Maximum length of the response.
    - temperature (float): Sampling temperature for randomness.

    Returns:
    - str: Generated response from the model.
    """
    response = generator(
        prompt,
        max_length=max_length,
        temperature=temperature,
        num_return_sequences=1,
        do_sample=True,
    )
    return response[0]["generated_text"]

# Creating a Gradio interface using Blocks
with gr.Blocks() as interface: # Use gr.Blocks()
    gr.Markdown("## Open Domain Question Answering Model") # Add title as Markdown
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(lines=5, label="Input Prompt")
            max_length = gr.Slider(50, 500, step=10, value=150, label="Max Length")
            temperature = gr.Slider(0.1, 1.0, step=0.1, value=0.7, label="Temperature")
            submit_btn = gr.Button("Generate")
        with gr.Column():
            response = gr.Textbox(label="Generated Response")

    # Defining the function call for the button
    submit_btn.click(
        fn=generate_response, 
        inputs=[prompt, max_length, temperature], 
        outputs=response
    )

# Launching the interface
interface.launch()
